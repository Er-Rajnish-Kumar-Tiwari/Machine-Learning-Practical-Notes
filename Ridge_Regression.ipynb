# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# %%
# Dummy Salary Dataset with column names
salary_data = {
    "data": [
        {"Name": "Alice", "Experience": 1, "Age": 22, "Education": "Bachelors", "SkillScore": 6, "Certifications": 0, "Salary": 30},
        {"Name": "Bob", "Experience": 2, "Age": 24, "Education": "Masters", "SkillScore": 7, "Certifications": 1, "Salary": 35},
        {"Name": "Charlie", "Experience": 3, "Age": 25, "Education": "Masters", "SkillScore": 8, "Certifications": 2, "Salary": 40},
        {"Name": "David", "Experience": 4, "Age": 27, "Education": "PhD", "SkillScore": 7, "Certifications": 2, "Salary": 45},
        {"Name": "Eva", "Experience": 5, "Age": 28, "Education": "PhD", "SkillScore": 9, "Certifications": 3, "Salary": 50},
        {"Name": "Frank", "Experience": 6, "Age": 30, "Education": "PhD", "SkillScore": 8, "Certifications": 2, "Salary": 55},
        {"Name": "Grace", "Experience": 7, "Age": 32, "Education": "PhD", "SkillScore": 9, "Certifications": 4, "Salary": 60},
        {"Name": "Hannah", "Experience": 8, "Age": 33, "Education": "PhD", "SkillScore": 10, "Certifications": 5, "Salary": 65},
        {"Name": "Ian", "Experience": 9, "Age": 35, "Education": "PhD", "SkillScore": 9, "Certifications": 4, "Salary": 70},
        {"Name": "Jack", "Experience": 10, "Age": 36, "Education": "PhD", "SkillScore": 10, "Certifications": 5, "Salary": 75},
        {"Name": "Kathy", "Experience": 1, "Age": 23, "Education": "Bachelors", "SkillScore": 5, "Certifications": 0, "Salary": 32},
        {"Name": "Leo", "Experience": 2, "Age": 25, "Education": "Masters", "SkillScore": 6, "Certifications": 1, "Salary": 37},
        {"Name": "Mona", "Experience": 3, "Age": 26, "Education": "Masters", "SkillScore": 7, "Certifications": 1, "Salary": 42},
        {"Name": "Nina", "Experience": 4, "Age": 28, "Education": "PhD", "SkillScore": 8, "Certifications": 2, "Salary": 47},
        {"Name": "Oscar", "Experience": 5, "Age": 29, "Education": "PhD", "SkillScore": 8, "Certifications": 2, "Salary": 52},
        {"Name": "Paul", "Experience": 6, "Age": 31, "Education": "PhD", "SkillScore": 9, "Certifications": 3, "Salary": 57},
        {"Name": "Quinn", "Experience": 7, "Age": 33, "Education": "PhD", "SkillScore": 9, "Certifications": 3, "Salary": 62},
        {"Name": "Rita", "Experience": 8, "Age": 34, "Education": "PhD", "SkillScore": 10, "Certifications": 4, "Salary": 67},
        {"Name": "Steve", "Experience": 9, "Age": 35, "Education": "PhD", "SkillScore": 10, "Certifications": 4, "Salary": 72},
        {"Name": "Tina", "Experience": 10, "Age": 37, "Education": "PhD", "SkillScore": 10, "Certifications": 5, "Salary": 77}
    ]
}

# %%
df=pd.DataFrame(salary_data["data"])

# %%
df=pd.get_dummies(df)

# %%
X=df.drop("Salary",axis=1)
y=df["Salary"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
ridge_reg=Ridge()

# %%
parameters={'alpha':[0.01,0.1,1,10,100]}

# %%
ridgecv=GridSearchCV(ridge_reg,parameters,scoring="neg_mean_squared_error",cv=5)
ridgecv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10, 100]},
#              scoring='neg_mean_squared_error')

# %%
print(ridgecv.best_score_)
# Out:
# -27.727562895407623

# %%
print(ridgecv.best_params_)
# Out:
# {'alpha': 0.01}

# %%
ridge_pre=ridgecv.predict(X_test)

# %%
plt.scatter(y_test, ridge_pre)

plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.title("Actual vs Predicted")

plt.grid()
plt.show()

# %%
r2=r2_score(y_test,ridge_pre)

# %%
r2
# Out:
# 0.9444303704110583
