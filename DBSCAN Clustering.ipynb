# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df=sns.load_dataset("iris")

# %%
X=df.iloc[:,:-1]

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
model=DBSCAN(eps=0.5)

# %%
cluster=model.fit_predict(X_scaled)

# %%
df["Cluster"]=cluster

# %%
mask = cluster != -1

if len(set(cluster[mask])) > 1:
    score=silhouette_score(X_scaled[mask],cluster[mask])
    print("Score",score)

else:
    print("Score can not be calculated")
# Out:
# Score 0.6558885287002018

# %%
plt.scatter(X_scaled[:,0],X_scaled[:,1],c=cluster)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("DBSCAN Clustering")

plt.show()
