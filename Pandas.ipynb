# %% [markdown]
# # Pandas Learning

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["Rajnsih","Tanish","Shivansh"],
    "marks":["92","95","94"]
}

# %%
dict1
# Out:
# {'name': ['Rajnsih', 'Tanish', 'Shivansh'], 'marks': ['92', '95', '94']}

# %%
df=pd.DataFrame(dict1)

# %%
df.to_csv("rajnish.csv",index=False)

# %%
df.head(1)
# Out:
#       name marks
# 0  Rajnsih    92

# %%
df.tail(1)
# Out:
#        name marks
# 2  Shivansh    94

# %%
df.describe()
# Out:
#            name marks
# count         3     3
# unique        3     3
# top     Rajnsih    92
# freq          1     1

# %%
df.max()
# Out:
# name     Tanish
# marks        95
# dtype: str

# %%
df.min()
# Out:
# name     Rajnsih
# marks         92
# dtype: str

# %%
rajnish=pd.read_csv("rajnish.csv")

# %%
rajnish
# Out:
#        name  marks
# 0   Rajnsih     92
# 1    Tanish     95
# 2  Shivansh     94

# %%
rajnish
# Out:
#        name  marks
# 0   Rajnsih     92
# 1    Tanish     95
# 2  Shivansh     94

# %%
rajnish.index=["1","2","3"]

# %%
rajnish
# Out:
#        name  marks
# 1   Rajnsih     92
# 2    Tanish     95
# 3  Shivansh     94

# %%
rajnish.to_csv("rajnish.csv")

# %%
newf=pd.DataFrame(np.random.rand(4,5),index=np.arange(4))

# %%
newf
# Out:
#           0         1         2         3         4
# 0  0.101610  0.308675  0.218748  0.131652  0.575945
# 1  0.882886  0.196165  0.426438  0.421545  0.603920
# 2  0.784348  0.743141  0.486074  0.607578  0.033418
# 3  0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf[0]
# Out:
# 0    0.101610
# 1    0.882886
# 2    0.784348
# 3    0.997499
# Name: 0, dtype: float64

# %%
type(newf)
# Out:
# pandas.DataFrame

# %%
type(newf[0])
# Out:
# pandas.Series

# %%
newf.T
# Out:
#           0         1         2         3
# 0  0.101610  0.882886  0.784348  0.997499
# 1  0.308675  0.196165  0.743141  0.311837
# 2  0.218748  0.426438  0.486074  0.880689
# 3  0.131652  0.421545  0.607578  0.612960
# 4  0.575945  0.603920  0.033418  0.850092

# %%
newf1=newf.copy()

# %%
newf1
# Out:
#           0         1         2         3         4
# 0  0.101610  0.308675  0.218748  0.131652  0.575945
# 1  0.882886  0.196165  0.426438  0.421545  0.603920
# 2  0.784348  0.743141  0.486074  0.607578  0.033418
# 3  0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.loc[0,0]=12

# %%
newf
# Out:
#            0         1         2         3         4
# 0  12.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf1.loc[0,0]=22

# %%
newf1
# Out:
#            0         1         2         3         4
# 0  22.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf
# Out:
#            0         1         2         3         4
# 0  12.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.columns=list("ABCDE")

# %%
newf
# Out:
#            A         B         C         D         E
# 0  12.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.loc[0,"A"]=28

# %%
newf
# Out:
#            A         B         C         D         E
# 0  28.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.drop("E",axis=1)
# Out:
#            A         B         C         D
# 0  28.000000  0.308675  0.218748  0.131652
# 1   0.882886  0.196165  0.426438  0.421545
# 2   0.784348  0.743141  0.486074  0.607578
# 3   0.997499  0.311837  0.880689  0.612960

# %%
newf.loc[[1,2],["A","B"]]
# Out:
#           A         B
# 1  0.882886  0.196165
# 2  0.784348  0.743141

# %%
newf.loc[:,["A","B"]]
# Out:
#            A         B
# 0  28.000000  0.308675
# 1   0.882886  0.196165
# 2   0.784348  0.743141
# 3   0.997499  0.311837

# %%
newf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.882886  0.196165  0.426438  0.421545  0.603920
# 2  0.784348  0.743141  0.486074  0.607578  0.033418

# %%
newf.loc[(newf["A"]<0.8) & (newf["E"]>0.4)]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
newf.iloc[0,3]
# Out:
# np.float64(0.13165230430687447)

# %%
newf.iloc[0,3]
# Out:
# np.float64(0.13165230430687447)

# %%
newf
# Out:
#            A         B         C         D         E
# 0  28.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.iloc[[0,1],[2,3]]
# Out:
#           C         D
# 0  0.218748  0.131652
# 1  0.426438  0.421545

# %%
newf.reset_index()
# Out:
#    index          A         B         C         D         E
# 0      0  28.000000  0.308675  0.218748  0.131652  0.575945
# 1      1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2      2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3      3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.reset_index(drop=True)
# Out:
#            A         B         C         D         E
# 0  28.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092

# %%
newf.info
# Out:
# <bound method DataFrame.info of            A         B         C         D         E
# 0  28.000000  0.308675  0.218748  0.131652  0.575945
# 1   0.882886  0.196165  0.426438  0.421545  0.603920
# 2   0.784348  0.743141  0.486074  0.607578  0.033418
# 3   0.997499  0.311837  0.880689  0.612960  0.850092>

# %%
df.value_counts(dropna=False)
# Out:
# name      marks
# Rajnsih   92       1
# Tanish    95       1
# Shivansh  94       1
# Name: count, dtype: int64

# %%
newf.notnull()
# Out:
#       A     B     C     D     E
# 0  True  True  True  True  True
# 1  True  True  True  True  True
# 2  True  True  True  True  True
# 3  True  True  True  True  True

# %%
newf.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False

# %%
newf.mean()
# Out:
# A    7.666183
# B    0.389955
# C    0.502987
# D    0.443434
# E    0.515844
# dtype: float64

# %%
newf.median()
# Out:
# A    0.940193
# B    0.310256
# C    0.456256
# D    0.514562
# E    0.589933
# dtype: float64
